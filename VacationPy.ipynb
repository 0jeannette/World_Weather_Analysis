# %%
# Import the dependencies.
import pandas as pd
import gmaps
import requests
# Import the API key.
from config import g_key

# %%
pip install gmaps
# Out:
# Requirement already satisfied: gmaps in c:\users\jeann\anaconda3\envs\pythondata\lib\site-packages (0.9.0)
# Requirement already satisfied: geojson>=2.0.0 in c:\users\jeann\anaconda3\envs\pythondata\lib\site-packages (from gmaps) (2.5.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in c:\users\jeann\anaconda3\envs\pythondata\lib\site-packages (from gmaps) (7.6.3)
# Requirement already satisfied: six in c:\users\jeann\anaconda3\envs\pythondata\lib\site-packages (from gmaps) (1.15.0)
# Requirement already satisfied: ipython>=5.3.0 in c:\users\jeann\anaconda3\envs\pythondata\lib\site-packages (from gmaps) (7.22.0)
# Requirement already satisfied: traitlets>=4.3.0 in c:\users\jeann\anaconda3\envs\pythondata\lib\site-packages (from gmaps) (5.0.5)
# Requirement already satisfied: backcall in c:\users\jeann\anaconda3\envs\pythondata\lib\site-packages (from ipython>=5.3.0->gmaps) (0.2.0)
# Requirement already satisfied: pickleshare in c:\users\jeann\anaconda3\envs\pythondata\lib\site-packages (from ipython>=5.3.0->gmaps) (0.7.5)
# Requirement already satisfied: colorama in c:\users\jeann\anaconda3\envs\pythondata\lib\site-packages (from ipython>=5.3.0->gmaps) (0.4.4)
# Requirement already satisfied: decorator in c:\users\jeann\anaconda3\envs\pythondata\lib\site-packages (from ipython>=5.3.0->gmaps) (5.0.6)
# Requirement already satisfied: pygments in c:\users\jeann\anaconda3\envs\pythondata\lib\site-packages (from ipython>=5.3.0->gmaps) (2.8.1)
# Requirement already satisfied: setuptools>=18.5 in c:\users\jeann\anaconda3\envs\pythondata\lib\site-packages (from ipython>=5.3.0->gmaps) (52.0.0.post20210125)
# Requirement already satisfied: jedi>=0.16 in c:\users\jeann\anaconda3\envs\pythondata\lib\site-packages (from ipython>=5.3.0->gmaps) (0.17.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\jeann\anaconda3\envs\pythondata\lib\site-packages (from ipython>=5.3.0->gmaps) (3.0.17)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\jeann\anaconda3\envs\pythondata\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (3.5.1)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\jeann\anaconda3\envs\pythondata\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (5.1.3)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\jeann\anaconda3\envs\pythondata\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (5.3.4)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\jeann\anaconda3\envs\pythondata\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (1.0.0)
# Requirement already satisfied: jupyter-client in c:\users\jeann\anaconda3\envs\pythondata\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in c:\users\jeann\anaconda3\envs\pythondata\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (6.1)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in c:\users\jeann\anaconda3\envs\pythondata\lib\site-packages (from jedi>=0.16->ipython>=5.3.0->gmaps) (0.7.0)
# Requirement already satisfied: jupyter-core in c:\users\jeann\anaconda3\envs\pythondata\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (4.7.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\jeann\anaconda3\envs\pythondata\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (3.2.0)
# Requirement already satisfied: ipython-genutils in c:\users\jeann\anaconda3\envs\pythondata\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (0.2.0)
# Requirement already satisfied: importlib-metadata in c:\users\jeann\anaconda3\envs\pythondata\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (3.10.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\jeann\anaconda3\envs\pythondata\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (0.17.3)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\jeann\anaconda3\envs\pythondata\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (20.3.0)
# Requirement already satisfied: wcwidth in c:\users\jeann\anaconda3\envs\pythondata\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->gmaps) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\jeann\anaconda3\envs\pythondata\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (6.3.0)
# Requirement already satisfied: prometheus-client in c:\users\jeann\anaconda3\envs\pythondata\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.10.1)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\jeann\anaconda3\envs\pythondata\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.9.4)
# Requirement already satisfied: argon2-cffi in c:\users\jeann\anaconda3\envs\pythondata\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (20.1.0)
# Requirement already satisfied: nbconvert in c:\users\jeann\anaconda3\envs\pythondata\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (6.0.7)
# Requirement already satisfied: Send2Trash>=1.5.0 in c:\users\jeann\anaconda3\envs\pythondata\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.5.0)
# Requirement already satisfied: pyzmq>=17 in c:\users\jeann\anaconda3\envs\pythondata\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (20.0.0)
# Requirement already satisfied: jinja2 in c:\users\jeann\anaconda3\envs\pythondata\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.11.3)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\jeann\anaconda3\envs\pythondata\lib\site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (2.8.1)
# Requirement already satisfied: pywin32>=1.0 in c:\users\jeann\anaconda3\envs\pythondata\lib\site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (227)
# Requirement already satisfied: pywinpty>=0.5 in c:\users\jeann\anaconda3\envs\pythondata\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.7)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\jeann\anaconda3\envs\pythondata\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.14.5)
# Requirement already satisfied: pycparser in c:\users\jeann\anaconda3\envs\pythondata\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.20)
# Requirement already satisfied: typing-extensions>=3.6.4 in c:\users\jeann\anaconda3\envs\pythondata\lib\site-packages (from importlib-metadata->jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in c:\users\jeann\anaconda3\envs\pythondata\lib\site-packages (from importlib-metadata->jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (3.4.1)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\jeann\anaconda3\envs\pythondata\lib\site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.1.1)
# Requirement already satisfied: bleach in c:\users\jeann\anaconda3\envs\pythondata\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (3.3.0)
# Requirement already satisfied: defusedxml in c:\users\jeann\anaconda3\envs\pythondata\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.7.1)
# Requirement already satisfied: testpath in c:\users\jeann\anaconda3\envs\pythondata\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.4.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\jeann\anaconda3\envs\pythondata\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.4.3)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\jeann\anaconda3\envs\pythondata\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\jeann\anaconda3\envs\pythondata\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.8.4)
# Requirement already satisfied: jupyterlab-pygments in c:\users\jeann\anaconda3\envs\pythondata\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.1.2)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\jeann\anaconda3\envs\pythondata\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.3)
# Requirement already satisfied: async-generator in c:\users\jeann\anaconda3\envs\pythondata\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.10)
# Requirement already satisfied: nest-asyncio in c:\users\jeann\anaconda3\envs\pythondata\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.5.1)
# Requirement already satisfied: packaging in c:\users\jeann\anaconda3\envs\pythondata\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (20.9)
# Requirement already satisfied: webencodings in c:\users\jeann\anaconda3\envs\pythondata\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.1)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\jeann\anaconda3\envs\pythondata\lib\site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.4.7)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Store the CSV you saved created in part one into a DataFrame.
city_data_df = pd.read_csv("weather_data/cities.csv")
city_data_df.head()
# Out:
#    City_ID           City Country                 Date      Lat       Lng  \
# 0        0        Kamenka      RU  2021-09-17 10:36:49  51.3223   42.7678
# 1        1         Dikson      RU  2021-09-17 10:36:49  73.5069   80.5464
# 2        2          Asyut      EG  2021-09-17 10:36:50  27.1810   31.1837
# 3        3  Srednekolymsk      RU  2021-09-17 10:36:50  67.4500  153.6833
# 4        4   Saint-Joseph      RE  2021-09-17 10:36:50 -21.3667   55.6167
#
#    Max Temp  Humidity  Cloudiness  Wind Speed
# 0     62.44        36          78        6.73
# 1     34.25        71         100       18.32
# 2     84.38        25           0       17.92
# 3     47.30        66          91        4.92
# 4     77.36        72          15        5.06

# %%
city_data_df.dtypes
# Out:
# City_ID         int64
# City           object
# Country        object
# Date           object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# dtype: object

# %%
# Configure gmaps to use your Google API key.
gmaps.configure(api_key=g_key)

# %%
# 1. Assign the locations to an array of latitude and longitude pairs.

locations = [latitude, longitude]

# 2. Assign the weights variable to some values.
temperatures = # an array of length equal to the locations array length

# 3. Assign the figure variable to the gmaps.figure() attribute.
fig = gmaps.figure()

# 4. Assign the heatmap_layer variable to the heatmap_layer attribute and add in the locations.
heatmap_layer = gmaps.heatmap_layer(locations, weights=temperatures)

# 5. Add the heatmap layer.
fig.add_layer(heatmap_layer)

# 6. Call the figure to plot the data.
fig
# Out:
#   File "<ipython-input-6-fb24e453e7f9>", line 6
#     temperatures = # an array of length equal to the locations array length
#                                                                            ^
# SyntaxError: invalid syntax

# %%
# Get the maximum temperature.
max_temp = city_data_df["Max Temp"]
temps = []
for temp in max_temp:
    temps.append(max(temp, 0))

# %%
# Heatmap of temperature
# Get the latitude and longitude.
locations = city_data_df[["Lat", "Lng"]]
# Get the maximum temperature.
max_temp = city_data_df["Max Temp"]
# Assign the figure variable.
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
# Assign the heatmap variable.
heat_layer = gmaps.heatmap_layer(locations, weights=[max(temp, 0) for temp in max_temp], dissipating=False, max_intensity=300, point_radius=4)
# Add the heatmap layer.
fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of percent humidity
locations = city_data_df[["Lat", "Lng"]]
humidity = city_data_df["Humidity"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=humidity, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of percent cloudiness
locations = city_data_df[["Lat", "Lng"]]
clouds = city_data_df["Cloudiness"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=clouds, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of percent cloudiness
locations = city_data_df[["Lat", "Lng"]]
wind = city_data_df["Wind Speed"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=wind, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Ask the customer to add a minimum and maximum temperature value.
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 75
# What is the maximum temperature you would like for your trip? 90

# %%
# Filter the dataset to find the cities that fit the criteria.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df.head(10)
# Out:
#     City_ID            City Country                 Date      Lat       Lng  \
# 2         2           Asyut      EG  2021-09-17 10:36:50  27.1810   31.1837
# 4         4    Saint-Joseph      RE  2021-09-17 10:36:50 -21.3667   55.6167
# 9         9    Port Hedland      AU  2021-09-17 10:36:52 -20.3167  118.5667
# 12       12            Hilo      US  2021-09-17 10:36:30  19.7297 -155.0900
# 23       23         Emerald      AU  2021-09-17 10:36:57 -23.5333  148.1667
# 25       25           Korla      CN  2021-09-17 10:36:58  41.7597   86.1469
# 31       31     Grand Gaube      MU  2021-09-17 10:37:00 -20.0064   57.6608
# 32       32  Cabo San Lucas      MX  2021-09-17 10:37:00  22.8909 -109.9124
# 35       35  Saint-Philippe      RE  2021-09-17 10:37:01 -21.3585   55.7679
# 37       37           Jaque      PA  2021-09-17 10:37:02   7.5175  -78.1703
#
#     Max Temp  Humidity  Cloudiness  Wind Speed
# 2      84.38        25           0       17.92
# 4      77.36        72          15        5.06
# 9      80.65        36          24       12.66
# 12     76.28        90          75        6.91
# 23     75.34        38           0       10.36
# 25     84.40        14          23        9.22
# 31     77.38        72          84        8.99
# 32     79.14        88          30        5.01
# 35     78.35        71          14        8.81
# 37     77.94        88          94        2.89

# %%
preferred_cities_df.count()
# Out:
# City_ID       197
# City          197
# Country       196
# Date          197
# Lat           197
# Lng           197
# Max Temp      197
# Humidity      197
# Cloudiness    197
# Wind Speed    197
# dtype: int64

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = preferred_cities_df[["City", "Country", "Max Temp", "Lat", "Lng"]].copy()
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#               City Country  Max Temp      Lat       Lng Hotel Name
# 2            Asyut      EG     84.38  27.1810   31.1837
# 4     Saint-Joseph      RE     77.36 -21.3667   55.6167
# 9     Port Hedland      AU     80.65 -20.3167  118.5667
# 12            Hilo      US     76.28  19.7297 -155.0900
# 23         Emerald      AU     75.34 -23.5333  148.1667
# 25           Korla      CN     84.40  41.7597   86.1469
# 31     Grand Gaube      MU     77.38 -20.0064   57.6608
# 32  Cabo San Lucas      MX     79.14  22.8909 -109.9124
# 35  Saint-Philippe      RE     78.35 -21.3585   55.7679
# 37           Jaque      PA     77.94   7.5175  -78.1703

# %%
# Set parameters to search for a hotel.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# %%
# Iterate through the DataFrame.
for index, row in hotel_df.iterrows():
    # Get the latitude and longitude.
    lat = row["Lat"]
    lng = row["Lng"]

    # Add the latitude and longitude to location key for the params dictionary.
    params["location"] = f"{lat},{lng}"

    # Use the search term: "lodging" and our latitude and longitude.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    # Make request and get the JSON data from the search.
    hotels = requests.get(base_url, params=params).json()
    # Grab the first hotel from the results and store the name.
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        print("Hotel not found... skipping.")
# Out:
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.

# %%
hotel_df
# Out:
#                    City Country  Max Temp      Lat       Lng  \
# 2                 Asyut      EG     84.38  27.1810   31.1837
# 4          Saint-Joseph      RE     77.36 -21.3667   55.6167
# 9          Port Hedland      AU     80.65 -20.3167  118.5667
# 12                 Hilo      US     76.28  19.7297 -155.0900
# 23              Emerald      AU     75.34 -23.5333  148.1667
# ..                  ...     ...       ...      ...       ...
# 548          Cheremnoye      RU     81.19  53.1697   83.2133
# 554            Homa Bay      KE     80.28  -0.5273   34.4571
# 555               Basco      PH     84.74  20.4487  121.9702
# 556  Sao Felix Do Xingu      BR     79.70  -6.6447  -51.9950
# 558            Mabaruma      GY     76.80   8.2000  -59.7833
#
#                         Hotel Name
# 2            Florence Hotel Assiut
# 4    "Plantation Bed and Breakfast
# 9              The Esplanade Hotel
# 12             Hilo Hawaiian Hotel
# 23               The Irish Village
# ..                             ...
# 548
# 554     ACK Guest House - Homa Bay
# 555              Nathaniel's Lodge
# 556              Rio Xingu Camping
# 558       Monty Brooms Guest House
#
# [197 rows x 6 columns]

# %%
# Add a heatmap of temperature for the vacation spots.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp, dissipating=False,
             max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Add a heatmap of temperature for the vacation spots and a pop-up marker for each city.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""
# Store the DataFrame Row.
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
