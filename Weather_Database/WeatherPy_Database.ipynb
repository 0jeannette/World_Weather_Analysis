# %%
# Import
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a new set of 2000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 770

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48f60651e46d8d5dad131a0eacc82603

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        city_weather = requests.get(city_url).json()
        
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        city_desc = city_weather['weather'][0]['description']
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Date": city_date,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | albany
# Processing Record 2 of Set 1 | evensk
# Processing Record 3 of Set 1 | teya
# Processing Record 4 of Set 1 | avarua
# Processing Record 5 of Set 1 | kapaa
# Processing Record 6 of Set 1 | nikolskoye
# Processing Record 7 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 8 of Set 1 | contai
# Processing Record 9 of Set 1 | thompson
# Processing Record 10 of Set 1 | busselton
# Processing Record 11 of Set 1 | lata
# Processing Record 12 of Set 1 | dunedin
# Processing Record 13 of Set 1 | damavand
# Processing Record 14 of Set 1 | port elizabeth
# Processing Record 15 of Set 1 | rikitea
# Processing Record 16 of Set 1 | bokspits
# City not found. Skipping...
# Processing Record 17 of Set 1 | butaritari
# Processing Record 18 of Set 1 | port hardy
# Processing Record 19 of Set 1 | pasighat
# Processing Record 20 of Set 1 | cape town
# Processing Record 21 of Set 1 | pevek
# Processing Record 22 of Set 1 | bonavista
# Processing Record 23 of Set 1 | manthani
# Processing Record 24 of Set 1 | bathsheba
# Processing Record 25 of Set 1 | airai
# Processing Record 26 of Set 1 | itarema
# Processing Record 27 of Set 1 | berlevag
# Processing Record 28 of Set 1 | deloraine
# Processing Record 29 of Set 1 | agadir
# Processing Record 30 of Set 1 | port macquarie
# Processing Record 31 of Set 1 | whitianga
# Processing Record 32 of Set 1 | deputatskiy
# Processing Record 33 of Set 1 | castro
# Processing Record 34 of Set 1 | naze
# Processing Record 35 of Set 1 | sovetskiy
# Processing Record 36 of Set 1 | hilo
# Processing Record 37 of Set 1 | jamestown
# Processing Record 38 of Set 1 | puerto ayacucho
# Processing Record 39 of Set 1 | villanueva
# Processing Record 40 of Set 1 | hermanus
# Processing Record 41 of Set 1 | vaini
# Processing Record 42 of Set 1 | bednodemyanovsk
# City not found. Skipping...
# Processing Record 43 of Set 1 | saint-philippe
# Processing Record 44 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 45 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 46 of Set 1 | veraval
# Processing Record 47 of Set 1 | altay
# Processing Record 48 of Set 1 | lethem
# Processing Record 49 of Set 1 | mersing
# Processing Record 50 of Set 1 | savannah bight
# Processing Record 1 of Set 2 | khambhat
# Processing Record 2 of Set 2 | hofn
# Processing Record 3 of Set 2 | sassandra
# Processing Record 4 of Set 2 | shenjiamen
# Processing Record 5 of Set 2 | san quintin
# Processing Record 6 of Set 2 | baghdad
# Processing Record 7 of Set 2 | bethel
# Processing Record 8 of Set 2 | guerrero negro
# Processing Record 9 of Set 2 | mar del plata
# Processing Record 10 of Set 2 | omboue
# Processing Record 11 of Set 2 | nanortalik
# Processing Record 12 of Set 2 | darlington
# Processing Record 13 of Set 2 | ushuaia
# Processing Record 14 of Set 2 | bambous virieux
# Processing Record 15 of Set 2 | puerto ayora
# Processing Record 16 of Set 2 | cabo san lucas
# Processing Record 17 of Set 2 | henties bay
# Processing Record 18 of Set 2 | bredasdorp
# Processing Record 19 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 20 of Set 2 | biskamzha
# Processing Record 21 of Set 2 | guarapari
# Processing Record 22 of Set 2 | faya
# Processing Record 23 of Set 2 | saint-pierre
# Processing Record 24 of Set 2 | new norfolk
# Processing Record 25 of Set 2 | baturaja
# Processing Record 26 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 27 of Set 2 | atuona
# Processing Record 28 of Set 2 | dikson
# Processing Record 29 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 30 of Set 2 | gorele
# Processing Record 31 of Set 2 | fortuna
# Processing Record 32 of Set 2 | qaanaaq
# Processing Record 33 of Set 2 | vostok
# Processing Record 34 of Set 2 | kaitangata
# Processing Record 35 of Set 2 | barrow
# Processing Record 36 of Set 2 | lerwick
# Processing Record 37 of Set 2 | shingu
# Processing Record 38 of Set 2 | alipur duar
# City not found. Skipping...
# Processing Record 39 of Set 2 | arraial do cabo
# Processing Record 40 of Set 2 | seoul
# Processing Record 41 of Set 2 | cayenne
# Processing Record 42 of Set 2 | naron
# Processing Record 43 of Set 2 | cherskiy
# Processing Record 44 of Set 2 | hobart
# Processing Record 45 of Set 2 | phuket
# Processing Record 46 of Set 2 | torbay
# Processing Record 47 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 48 of Set 2 | ponta do sol
# Processing Record 49 of Set 2 | lompoc
# Processing Record 50 of Set 2 | olafsvik
# Processing Record 1 of Set 3 | kodiak
# Processing Record 2 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 3 of Set 3 | olkhovka
# Processing Record 4 of Set 3 | tuktoyaktuk
# Processing Record 5 of Set 3 | road town
# Processing Record 6 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 7 of Set 3 | ixtapa
# Processing Record 8 of Set 3 | svetlyy
# Processing Record 9 of Set 3 | praia da vitoria
# Processing Record 10 of Set 3 | aklavik
# Processing Record 11 of Set 3 | narsaq
# Processing Record 12 of Set 3 | greifswald
# Processing Record 13 of Set 3 | same
# Processing Record 14 of Set 3 | tazovskiy
# Processing Record 15 of Set 3 | pisco
# Processing Record 16 of Set 3 | luanda
# Processing Record 17 of Set 3 | port alfred
# Processing Record 18 of Set 3 | saskylakh
# Processing Record 19 of Set 3 | bluff
# Processing Record 20 of Set 3 | sorong
# Processing Record 21 of Set 3 | muros
# Processing Record 22 of Set 3 | yellowknife
# Processing Record 23 of Set 3 | colares
# Processing Record 24 of Set 3 | neiafu
# Processing Record 25 of Set 3 | mataura
# Processing Record 26 of Set 3 | paamiut
# Processing Record 27 of Set 3 | keningau
# Processing Record 28 of Set 3 | cidreira
# Processing Record 29 of Set 3 | san francisco
# Processing Record 30 of Set 3 | el dovio
# Processing Record 31 of Set 3 | upernavik
# Processing Record 32 of Set 3 | pitimbu
# Processing Record 33 of Set 3 | esperance
# Processing Record 34 of Set 3 | pueblo nuevo
# Processing Record 35 of Set 3 | malanje
# Processing Record 36 of Set 3 | turukhansk
# Processing Record 37 of Set 3 | calugareni
# Processing Record 38 of Set 3 | provideniya
# Processing Record 39 of Set 3 | punta arenas
# Processing Record 40 of Set 3 | xai-xai
# Processing Record 41 of Set 3 | malmesbury
# Processing Record 42 of Set 3 | buenos aires
# Processing Record 43 of Set 3 | mayumba
# Processing Record 44 of Set 3 | beloha
# Processing Record 45 of Set 3 | faanui
# Processing Record 46 of Set 3 | mao
# Processing Record 47 of Set 3 | juegang
# Processing Record 48 of Set 3 | san lorenzo
# Processing Record 49 of Set 3 | jiangyin
# Processing Record 50 of Set 3 | raton
# Processing Record 1 of Set 4 | kavieng
# Processing Record 2 of Set 4 | talnakh
# Processing Record 3 of Set 4 | sechura
# Processing Record 4 of Set 4 | alofi
# Processing Record 5 of Set 4 | ronne
# Processing Record 6 of Set 4 | ilulissat
# Processing Record 7 of Set 4 | kahului
# Processing Record 8 of Set 4 | alice springs
# Processing Record 9 of Set 4 | nizhniy chir
# Processing Record 10 of Set 4 | longyearbyen
# Processing Record 11 of Set 4 | loiza
# Processing Record 12 of Set 4 | clyde river
# Processing Record 13 of Set 4 | chokurdakh
# Processing Record 14 of Set 4 | sault sainte marie
# Processing Record 15 of Set 4 | hasaki
# Processing Record 16 of Set 4 | bosansko grahovo
# Processing Record 17 of Set 4 | chuy
# Processing Record 18 of Set 4 | quatre cocos
# Processing Record 19 of Set 4 | harer
# Processing Record 20 of Set 4 | toowoomba
# Processing Record 21 of Set 4 | leningradskiy
# Processing Record 22 of Set 4 | praya
# Processing Record 23 of Set 4 | alta floresta
# Processing Record 24 of Set 4 | nome
# Processing Record 25 of Set 4 | ribeira grande
# Processing Record 26 of Set 4 | san cristobal
# Processing Record 27 of Set 4 | srandakan
# Processing Record 28 of Set 4 | zaysan
# Processing Record 29 of Set 4 | mastic beach
# Processing Record 30 of Set 4 | iqaluit
# Processing Record 31 of Set 4 | nuevo laredo
# Processing Record 32 of Set 4 | east london
# Processing Record 33 of Set 4 | kirakira
# Processing Record 34 of Set 4 | lokosovo
# Processing Record 35 of Set 4 | anadyr
# Processing Record 36 of Set 4 | diadi
# Processing Record 37 of Set 4 | quang ngai
# Processing Record 38 of Set 4 | naryan-mar
# Processing Record 39 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 40 of Set 4 | fairbanks
# Processing Record 41 of Set 4 | lavrentiya
# Processing Record 42 of Set 4 | urdzhar
# City not found. Skipping...
# Processing Record 43 of Set 4 | souillac
# Processing Record 44 of Set 4 | athlone
# Processing Record 45 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 46 of Set 4 | ballina
# Processing Record 47 of Set 4 | saint george
# Processing Record 48 of Set 4 | mahebourg
# Processing Record 49 of Set 4 | marrakesh
# Processing Record 50 of Set 4 | shenzhen
# Processing Record 1 of Set 5 | lasa
# Processing Record 2 of Set 5 | verkhnetulomskiy
# Processing Record 3 of Set 5 | namibe
# Processing Record 4 of Set 5 | panjwin
# City not found. Skipping...
# Processing Record 5 of Set 5 | koumac
# Processing Record 6 of Set 5 | sarangani
# Processing Record 7 of Set 5 | yulara
# Processing Record 8 of Set 5 | bahia honda
# Processing Record 9 of Set 5 | grindavik
# Processing Record 10 of Set 5 | mgachi
# Processing Record 11 of Set 5 | cajamarca
# Processing Record 12 of Set 5 | dingle
# Processing Record 13 of Set 5 | dukat
# Processing Record 14 of Set 5 | kruisfontein
# Processing Record 15 of Set 5 | milkovo
# Processing Record 16 of Set 5 | anori
# Processing Record 17 of Set 5 | paranhos
# Processing Record 18 of Set 5 | codrington
# Processing Record 19 of Set 5 | inderborskiy
# City not found. Skipping...
# Processing Record 20 of Set 5 | veseli nad luznici
# Processing Record 21 of Set 5 | holt
# Processing Record 22 of Set 5 | tuggurt
# City not found. Skipping...
# Processing Record 23 of Set 5 | itaituba
# Processing Record 24 of Set 5 | bar-le-duc
# Processing Record 25 of Set 5 | husavik
# Processing Record 26 of Set 5 | ginda
# Processing Record 27 of Set 5 | college
# Processing Record 28 of Set 5 | rio verde de mato grosso
# Processing Record 29 of Set 5 | tiksi
# Processing Record 30 of Set 5 | moen
# Processing Record 31 of Set 5 | vila franca do campo
# Processing Record 32 of Set 5 | inirida
# Processing Record 33 of Set 5 | manzhouli
# Processing Record 34 of Set 5 | hambantota
# Processing Record 35 of Set 5 | sibolga
# Processing Record 36 of Set 5 | barao de melgaco
# Processing Record 37 of Set 5 | richards bay
# Processing Record 38 of Set 5 | zolotinka
# City not found. Skipping...
# Processing Record 39 of Set 5 | luderitz
# Processing Record 40 of Set 5 | yenagoa
# Processing Record 41 of Set 5 | bilma
# Processing Record 42 of Set 5 | dali
# Processing Record 43 of Set 5 | fort nelson
# Processing Record 44 of Set 5 | korem
# Processing Record 45 of Set 5 | port lincoln
# Processing Record 46 of Set 5 | yatou
# Processing Record 47 of Set 5 | buin
# Processing Record 48 of Set 5 | tuscaloosa
# Processing Record 49 of Set 5 | giresun
# Processing Record 50 of Set 5 | niamey
# Processing Record 1 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 2 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 3 of Set 6 | magadan
# Processing Record 4 of Set 6 | severo-kurilsk
# Processing Record 5 of Set 6 | conakry
# Processing Record 6 of Set 6 | sampang
# Processing Record 7 of Set 6 | romitan
# Processing Record 8 of Set 6 | laredo
# Processing Record 9 of Set 6 | seydi
# Processing Record 10 of Set 6 | geraldton
# Processing Record 11 of Set 6 | yunjinghong
# City not found. Skipping...
# Processing Record 12 of Set 6 | chokwe
# Processing Record 13 of Set 6 | espita
# Processing Record 14 of Set 6 | kaseda
# Processing Record 15 of Set 6 | san policarpo
# Processing Record 16 of Set 6 | saint anthony
# Processing Record 17 of Set 6 | sao filipe
# Processing Record 18 of Set 6 | bulgan
# Processing Record 19 of Set 6 | kosikha
# Processing Record 20 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 21 of Set 6 | srednekolymsk
# Processing Record 22 of Set 6 | la ronge
# Processing Record 23 of Set 6 | floro
# Processing Record 24 of Set 6 | khatanga
# Processing Record 25 of Set 6 | augusto correa
# Processing Record 26 of Set 6 | tanabe
# Processing Record 27 of Set 6 | kununurra
# Processing Record 28 of Set 6 | machaneng
# Processing Record 29 of Set 6 | ayios matthaios
# City not found. Skipping...
# Processing Record 30 of Set 6 | krasnyy
# Processing Record 31 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 32 of Set 6 | khonuu
# City not found. Skipping...
# Processing Record 33 of Set 6 | port hedland
# Processing Record 34 of Set 6 | kloulklubed
# Processing Record 35 of Set 6 | thinadhoo
# Processing Record 36 of Set 6 | mana
# Processing Record 37 of Set 6 | lapi
# Processing Record 38 of Set 6 | lagoa
# Processing Record 39 of Set 6 | ucluelet
# Processing Record 40 of Set 6 | rong kwang
# Processing Record 41 of Set 6 | vestmannaeyjar
# Processing Record 42 of Set 6 | karratha
# Processing Record 43 of Set 6 | puerto escondido
# Processing Record 44 of Set 6 | port hawkesbury
# Processing Record 45 of Set 6 | swift current
# Processing Record 46 of Set 6 | alenquer
# Processing Record 47 of Set 6 | vanimo
# Processing Record 48 of Set 6 | ankang
# Processing Record 49 of Set 6 | sheffield
# Processing Record 50 of Set 6 | los llanos de aridane
# Processing Record 1 of Set 7 | makakilo city
# Processing Record 2 of Set 7 | traverse city
# Processing Record 3 of Set 7 | chihuahua
# Processing Record 4 of Set 7 | esmeraldas
# Processing Record 5 of Set 7 | inhambane
# Processing Record 6 of Set 7 | mercedes
# Processing Record 7 of Set 7 | pangnirtung
# Processing Record 8 of Set 7 | arlit
# Processing Record 9 of Set 7 | raudeberg
# Processing Record 10 of Set 7 | carnarvon
# Processing Record 11 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 12 of Set 7 | manicore
# Processing Record 13 of Set 7 | dargaville
# Processing Record 14 of Set 7 | hithadhoo
# Processing Record 15 of Set 7 | georgetown
# Processing Record 16 of Set 7 | aban
# Processing Record 17 of Set 7 | boa esperanca
# Processing Record 18 of Set 7 | banda aceh
# Processing Record 19 of Set 7 | fiumicino
# Processing Record 20 of Set 7 | yunhe
# Processing Record 21 of Set 7 | qianjiang
# Processing Record 22 of Set 7 | grand gaube
# Processing Record 23 of Set 7 | banjar
# Processing Record 24 of Set 7 | tasiilaq
# Processing Record 25 of Set 7 | vila velha
# Processing Record 26 of Set 7 | bengkulu
# Processing Record 27 of Set 7 | marsh harbour
# Processing Record 28 of Set 7 | tabou
# Processing Record 29 of Set 7 | marfino
# Processing Record 30 of Set 7 | iquique
# Processing Record 31 of Set 7 | nuuk
# Processing Record 32 of Set 7 | honiara
# Processing Record 33 of Set 7 | solnechnyy
# Processing Record 34 of Set 7 | dubrovnik
# Processing Record 35 of Set 7 | ancud
# Processing Record 36 of Set 7 | monroe
# Processing Record 37 of Set 7 | hede
# Processing Record 38 of Set 7 | romodanovo
# Processing Record 39 of Set 7 | asau
# Processing Record 40 of Set 7 | hamilton
# Processing Record 41 of Set 7 | poum
# Processing Record 42 of Set 7 | varkaus
# Processing Record 43 of Set 7 | zaraza
# Processing Record 44 of Set 7 | chunskiy
# Processing Record 45 of Set 7 | rio grande
# Processing Record 46 of Set 7 | emerald
# Processing Record 47 of Set 7 | nemuro
# Processing Record 48 of Set 7 | franklin
# Processing Record 49 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 50 of Set 7 | rondonopolis
# Processing Record 1 of Set 8 | yambio
# Processing Record 2 of Set 8 | barra do bugres
# Processing Record 3 of Set 8 | marau
# Processing Record 4 of Set 8 | talara
# Processing Record 5 of Set 8 | bay roberts
# Processing Record 6 of Set 8 | comodoro rivadavia
# Processing Record 7 of Set 8 | burica
# City not found. Skipping...
# Processing Record 8 of Set 8 | ratanpur
# Processing Record 9 of Set 8 | norrtalje
# Processing Record 10 of Set 8 | leh
# Processing Record 11 of Set 8 | chabahar
# Processing Record 12 of Set 8 | jieshi
# Processing Record 13 of Set 8 | ola
# Processing Record 14 of Set 8 | bardiyah
# Processing Record 15 of Set 8 | matara
# Processing Record 16 of Set 8 | pangody
# Processing Record 17 of Set 8 | qui nhon
# Processing Record 18 of Set 8 | tawang
# Processing Record 19 of Set 8 | hualmay
# Processing Record 20 of Set 8 | kjollefjord
# Processing Record 21 of Set 8 | skjervoy
# Processing Record 22 of Set 8 | kaiyuan
# Processing Record 23 of Set 8 | tuatapere
# Processing Record 24 of Set 8 | touros
# Processing Record 25 of Set 8 | salinas
# Processing Record 26 of Set 8 | greencastle
# Processing Record 27 of Set 8 | tomatlan
# Processing Record 28 of Set 8 | kadykchan
# City not found. Skipping...
# Processing Record 29 of Set 8 | marzuq
# Processing Record 30 of Set 8 | marystown
# Processing Record 31 of Set 8 | sioux lookout
# Processing Record 32 of Set 8 | muroto
# Processing Record 33 of Set 8 | bossangoa
# Processing Record 34 of Set 8 | sterling
# Processing Record 35 of Set 8 | comarapa
# Processing Record 36 of Set 8 | saldanha
# Processing Record 37 of Set 8 | angoche
# Processing Record 38 of Set 8 | naliya
# Processing Record 39 of Set 8 | saebovik
# City not found. Skipping...
# Processing Record 40 of Set 8 | cabedelo
# Processing Record 41 of Set 8 | manbij
# Processing Record 42 of Set 8 | sur
# Processing Record 43 of Set 8 | kolimvari
# City not found. Skipping...
# Processing Record 44 of Set 8 | rawannawi
# City not found. Skipping...
# Processing Record 45 of Set 8 | cairns
# Processing Record 46 of Set 8 | lorengau
# Processing Record 47 of Set 8 | barghat
# Processing Record 48 of Set 8 | anda
# Processing Record 49 of Set 8 | gelterkinden
# Processing Record 50 of Set 8 | lucea
# Processing Record 1 of Set 9 | byron bay
# Processing Record 2 of Set 9 | calama
# Processing Record 3 of Set 9 | brae
# Processing Record 4 of Set 9 | vardo
# Processing Record 5 of Set 9 | guzelyurt
# Processing Record 6 of Set 9 | sangar
# Processing Record 7 of Set 9 | okakarara
# Processing Record 8 of Set 9 | xining
# Processing Record 9 of Set 9 | slave lake
# Processing Record 10 of Set 9 | amapa
# Processing Record 11 of Set 9 | barcelos
# Processing Record 12 of Set 9 | tubruq
# City not found. Skipping...
# Processing Record 13 of Set 9 | bartica
# Processing Record 14 of Set 9 | qobustan
# Processing Record 15 of Set 9 | coihaique
# Processing Record 16 of Set 9 | kavaratti
# Processing Record 17 of Set 9 | aswan
# Processing Record 18 of Set 9 | gizo
# Processing Record 19 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 20 of Set 9 | batticaloa
# Processing Record 21 of Set 9 | lampa
# Processing Record 22 of Set 9 | ranong
# Processing Record 23 of Set 9 | victoria
# Processing Record 24 of Set 9 | leiva
# Processing Record 25 of Set 9 | erenhot
# Processing Record 26 of Set 9 | namatanai
# Processing Record 27 of Set 9 | sobolevo
# Processing Record 28 of Set 9 | high prairie
# Processing Record 29 of Set 9 | agdam
# Processing Record 30 of Set 9 | ust-barguzin
# Processing Record 31 of Set 9 | senmonorom
# City not found. Skipping...
# Processing Record 32 of Set 9 | half moon bay
# Processing Record 33 of Set 9 | itoman
# Processing Record 34 of Set 9 | lubyany
# Processing Record 35 of Set 9 | puerto leguizamo
# Processing Record 36 of Set 9 | colac
# Processing Record 37 of Set 9 | chicama
# Processing Record 38 of Set 9 | okato
# Processing Record 39 of Set 9 | bubaque
# Processing Record 40 of Set 9 | menongue
# Processing Record 41 of Set 9 | adrar
# Processing Record 42 of Set 9 | trofors
# Processing Record 43 of Set 9 | amderma
# City not found. Skipping...
# Processing Record 44 of Set 9 | constitucion
# Processing Record 45 of Set 9 | aginskoye
# Processing Record 46 of Set 9 | tunxi
# City not found. Skipping...
# Processing Record 47 of Set 9 | mutis
# Processing Record 48 of Set 9 | norman wells
# Processing Record 49 of Set 9 | riyadh
# Processing Record 50 of Set 9 | bom jesus da lapa
# Processing Record 1 of Set 10 | hami
# Processing Record 2 of Set 10 | belmonte
# Processing Record 3 of Set 10 | samarai
# Processing Record 4 of Set 10 | misratah
# Processing Record 5 of Set 10 | zhenlai
# Processing Record 6 of Set 10 | anloga
# Processing Record 7 of Set 10 | shipitsyno
# Processing Record 8 of Set 10 | norden
# Processing Record 9 of Set 10 | alyangula
# Processing Record 10 of Set 10 | lebu
# Processing Record 11 of Set 10 | maltahohe
# Processing Record 12 of Set 10 | karkaralinsk
# City not found. Skipping...
# Processing Record 13 of Set 10 | plettenberg bay
# Processing Record 14 of Set 10 | miles city
# Processing Record 15 of Set 10 | felidhoo
# City not found. Skipping...
# Processing Record 16 of Set 10 | port-gentil
# Processing Record 17 of Set 10 | mitsamiouli
# Processing Record 18 of Set 10 | biloela
# Processing Record 19 of Set 10 | burns lake
# Processing Record 20 of Set 10 | peniche
# Processing Record 21 of Set 10 | nyamuswa
# Processing Record 22 of Set 10 | tautira
# Processing Record 23 of Set 10 | burnie
# Processing Record 24 of Set 10 | bud
# Processing Record 25 of Set 10 | mutoko
# Processing Record 26 of Set 10 | kosonsoy
# Processing Record 27 of Set 10 | bermeo
# Processing Record 28 of Set 10 | montague
# Processing Record 29 of Set 10 | antofagasta
# Processing Record 30 of Set 10 | dzhusaly
# City not found. Skipping...
# Processing Record 31 of Set 10 | margate
# Processing Record 32 of Set 10 | yomitan
# City not found. Skipping...
# Processing Record 33 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 34 of Set 10 | grand forks
# Processing Record 35 of Set 10 | ijaki
# City not found. Skipping...
# Processing Record 36 of Set 10 | boshnyakovo
# Processing Record 37 of Set 10 | mazatan
# Processing Record 38 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 39 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 40 of Set 10 | haines junction
# Processing Record 41 of Set 10 | taltal
# Processing Record 42 of Set 10 | mount isa
# Processing Record 43 of Set 10 | daru
# Processing Record 44 of Set 10 | bambui
# Processing Record 45 of Set 10 | camalu
# Processing Record 46 of Set 10 | owando
# Processing Record 47 of Set 10 | ahipara
# Processing Record 48 of Set 10 | melo
# Processing Record 49 of Set 10 | ust-kulom
# Processing Record 50 of Set 10 | shuyskoye
# Processing Record 1 of Set 11 | isangel
# Processing Record 2 of Set 11 | halifax
# Processing Record 3 of Set 11 | billings
# Processing Record 4 of Set 11 | vila
# Processing Record 5 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 6 of Set 11 | tenosique
# Processing Record 7 of Set 11 | rumuruti
# Processing Record 8 of Set 11 | ambulu
# Processing Record 9 of Set 11 | gat
# Processing Record 10 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 11 of Set 11 | peleduy
# Processing Record 12 of Set 11 | ketchikan
# Processing Record 13 of Set 11 | aykhal
# Processing Record 14 of Set 11 | nalut
# Processing Record 15 of Set 11 | moshi
# Processing Record 16 of Set 11 | carutapera
# Processing Record 17 of Set 11 | mitu
# Processing Record 18 of Set 11 | vangaindrano
# Processing Record 19 of Set 11 | viligili
# City not found. Skipping...
# Processing Record 20 of Set 11 | achisay
# City not found. Skipping...
# Processing Record 21 of Set 11 | bandar-e lengeh
# Processing Record 22 of Set 11 | liberal
# Processing Record 23 of Set 11 | yuli
# Processing Record 24 of Set 11 | rio gallegos
# Processing Record 25 of Set 11 | puerto narino
# Processing Record 26 of Set 11 | urumqi
# Processing Record 27 of Set 11 | marga
# Processing Record 28 of Set 11 | shelburne
# Processing Record 29 of Set 11 | namtsy
# Processing Record 30 of Set 11 | conceicao da barra
# Processing Record 31 of Set 11 | estelle
# Processing Record 32 of Set 11 | mount gambier
# Processing Record 33 of Set 11 | port blair
# Processing Record 34 of Set 11 | oriximina
# Processing Record 35 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 36 of Set 11 | ostersund
# Processing Record 37 of Set 11 | kirkenes
# Processing Record 38 of Set 11 | mattru
# Processing Record 39 of Set 11 | sitka
# Processing Record 40 of Set 11 | baykit
# Processing Record 41 of Set 11 | itabaianinha
# Processing Record 42 of Set 11 | nayudupeta
# Processing Record 43 of Set 11 | axim
# Processing Record 44 of Set 11 | ornskoldsvik
# Processing Record 45 of Set 11 | knyaginino
# Processing Record 46 of Set 11 | kieta
# Processing Record 47 of Set 11 | vastervik
# City not found. Skipping...
# Processing Record 48 of Set 11 | synya
# Processing Record 49 of Set 11 | maymanak
# City not found. Skipping...
# Processing Record 50 of Set 11 | lensk
# Processing Record 1 of Set 12 | haapiti
# Processing Record 2 of Set 12 | nynashamn
# Processing Record 3 of Set 12 | wampusirpi
# City not found. Skipping...
# Processing Record 4 of Set 12 | roald
# Processing Record 5 of Set 12 | nastola
# Processing Record 6 of Set 12 | turbat
# Processing Record 7 of Set 12 | saint-augustin
# Processing Record 8 of Set 12 | kingston
# Processing Record 9 of Set 12 | shamkhal
# Processing Record 10 of Set 12 | bilibino
# Processing Record 11 of Set 12 | los barrios
# Processing Record 12 of Set 12 | komsomolskiy
# Processing Record 13 of Set 12 | nioro
# Processing Record 14 of Set 12 | viedma
# Processing Record 15 of Set 12 | bensonville
# Processing Record 16 of Set 12 | tommot
# Processing Record 17 of Set 12 | sasykoli
# Processing Record 18 of Set 12 | mayo
# Processing Record 19 of Set 12 | mezen
# Processing Record 20 of Set 12 | guaruja
# Processing Record 21 of Set 12 | salihorsk
# Processing Record 22 of Set 12 | herat
# Processing Record 23 of Set 12 | nouadhibou
# Processing Record 24 of Set 12 | show low
# Processing Record 25 of Set 12 | davidson
# Processing Record 26 of Set 12 | romny
# Processing Record 27 of Set 12 | tarko-sale
# Processing Record 28 of Set 12 | urucara
# Processing Record 29 of Set 12 | qaqortoq
# Processing Record 30 of Set 12 | mpika
# Processing Record 31 of Set 12 | makat
# Processing Record 32 of Set 12 | mayya
# Processing Record 33 of Set 12 | pimentel
# Processing Record 34 of Set 12 | khargone
# Processing Record 35 of Set 12 | tupik
# Processing Record 36 of Set 12 | jahrom
# City not found. Skipping...
# Processing Record 37 of Set 12 | smithers
# Processing Record 38 of Set 12 | maarianhamina
# Processing Record 39 of Set 12 | benguela
# Processing Record 40 of Set 12 | terrace bay
# Processing Record 41 of Set 12 | porto empedocle
# Processing Record 42 of Set 12 | sao jose da coroa grande
# Processing Record 43 of Set 12 | borgarnes
# Processing Record 44 of Set 12 | skagastrond
# City not found. Skipping...
# Processing Record 45 of Set 12 | tasbuget
# City not found. Skipping...
# Processing Record 46 of Set 12 | christchurch
# Processing Record 47 of Set 12 | porto torres
# Processing Record 48 of Set 12 | cartagena
# Processing Record 49 of Set 12 | clearwater
# Processing Record 50 of Set 12 | les trois-ilets
# Processing Record 1 of Set 13 | kyabe
# Processing Record 2 of Set 13 | poco verde
# Processing Record 3 of Set 13 | acarau
# Processing Record 4 of Set 13 | churapcha
# Processing Record 5 of Set 13 | puerto del rosario
# Processing Record 6 of Set 13 | arzgir
# Processing Record 7 of Set 13 | katsuura
# Processing Record 8 of Set 13 | mogilno
# Processing Record 9 of Set 13 | huarmey
# Processing Record 10 of Set 13 | vagay
# Processing Record 11 of Set 13 | acapulco
# Processing Record 12 of Set 13 | yinchuan
# Processing Record 13 of Set 13 | izacic
# Processing Record 14 of Set 13 | tambopata
# Processing Record 15 of Set 13 | wum
# Processing Record 16 of Set 13 | verkhoyansk
# Processing Record 17 of Set 13 | apolda
# Processing Record 18 of Set 13 | ust-shonosha
# Processing Record 19 of Set 13 | flinders
# Processing Record 20 of Set 13 | juan aldama
# Processing Record 21 of Set 13 | korla
# Processing Record 22 of Set 13 | noumea
# Processing Record 23 of Set 13 | saint-francois
# Processing Record 24 of Set 13 | bolshoy uluy
# City not found. Skipping...
# Processing Record 25 of Set 13 | mandal
# Processing Record 26 of Set 13 | yelan
# Processing Record 27 of Set 13 | kisangani
# Processing Record 28 of Set 13 | nacunday
# City not found. Skipping...
# Processing Record 29 of Set 13 | gornopravdinsk
# Processing Record 30 of Set 13 | coracao de jesus
# Processing Record 31 of Set 13 | damietta
# Processing Record 32 of Set 13 | vikhorevka
# Processing Record 33 of Set 13 | auki
# Processing Record 34 of Set 13 | abapo
# Processing Record 35 of Set 13 | cap malheureux
# Processing Record 36 of Set 13 | nowa sol
# Processing Record 37 of Set 13 | diego de almagro
# Processing Record 38 of Set 13 | broken hill
# Processing Record 39 of Set 13 | pryozerne
# Processing Record 40 of Set 13 | huangmei
# Processing Record 41 of Set 13 | malwan
# City not found. Skipping...
# Processing Record 42 of Set 13 | yumen
# Processing Record 43 of Set 13 | gilleleje
# Processing Record 44 of Set 13 | kula
# Processing Record 45 of Set 13 | nara
# Processing Record 46 of Set 13 | musoma
# Processing Record 47 of Set 13 | hazorasp
# Processing Record 48 of Set 13 | santa cruz
# Processing Record 49 of Set 13 | mehamn
# Processing Record 50 of Set 13 | gamba
# Processing Record 1 of Set 14 | tevaitoa
# Processing Record 2 of Set 14 | atar
# Processing Record 3 of Set 14 | malaryta
# Processing Record 4 of Set 14 | florianopolis
# Processing Record 5 of Set 14 | koudougou
# Processing Record 6 of Set 14 | abu dhabi
# Processing Record 7 of Set 14 | yartsevo
# Processing Record 8 of Set 14 | havre-saint-pierre
# Processing Record 9 of Set 14 | waddan
# Processing Record 10 of Set 14 | broome
# Processing Record 11 of Set 14 | kalmunai
# Processing Record 12 of Set 14 | gbarnga
# Processing Record 13 of Set 14 | behshahr
# Processing Record 14 of Set 14 | nuevitas
# Processing Record 15 of Set 14 | piacabucu
# Processing Record 16 of Set 14 | kualakapuas
# Processing Record 17 of Set 14 | pahrump
# Processing Record 18 of Set 14 | bella vista
# Processing Record 19 of Set 14 | atasu
# Processing Record 20 of Set 14 | tsumeb
# Processing Record 21 of Set 14 | fukuma
# Processing Record 22 of Set 14 | thai binh
# Processing Record 23 of Set 14 | magadi
# Processing Record 24 of Set 14 | ushtobe
# Processing Record 25 of Set 14 | hovd
# Processing Record 26 of Set 14 | manzanillo
# Processing Record 27 of Set 14 | waipawa
# Processing Record 28 of Set 14 | at-bashi
# Processing Record 29 of Set 14 | yamada
# Processing Record 30 of Set 14 | sindgi
# Processing Record 31 of Set 14 | neya
# Processing Record 32 of Set 14 | griffith
# Processing Record 33 of Set 14 | san patricio
# Processing Record 34 of Set 14 | ozgon
# City not found. Skipping...
# Processing Record 35 of Set 14 | tilichiki
# Processing Record 36 of Set 14 | biak
# Processing Record 37 of Set 14 | orlik
# Processing Record 38 of Set 14 | sisimiut
# Processing Record 39 of Set 14 | arroyo
# Processing Record 40 of Set 14 | jiwani
# Processing Record 41 of Set 14 | ondarroa
# Processing Record 42 of Set 14 | voisiku
# City not found. Skipping...
# Processing Record 43 of Set 14 | whitehorse
# Processing Record 44 of Set 14 | ambilobe
# Processing Record 45 of Set 14 | ishigaki
# Processing Record 46 of Set 14 | sola
# Processing Record 47 of Set 14 | eureka
# Processing Record 48 of Set 14 | stepnyak
# Processing Record 49 of Set 14 | bambanglipuro
# Processing Record 50 of Set 14 | barbar
# City not found. Skipping...
# Processing Record 1 of Set 15 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 2 of Set 15 | nelson bay
# Processing Record 3 of Set 15 | taksimo
# Processing Record 4 of Set 15 | brewster
# Processing Record 5 of Set 15 | nong han
# Processing Record 6 of Set 15 | nanakuli
# Processing Record 7 of Set 15 | mwinilunga
# Processing Record 8 of Set 15 | ilheus
# Processing Record 9 of Set 15 | amarpur
# Processing Record 10 of Set 15 | luganville
# Processing Record 11 of Set 15 | rabaul
# Processing Record 12 of Set 15 | rosario
# Processing Record 13 of Set 15 | mogadishu
# Processing Record 14 of Set 15 | hundested
# Processing Record 15 of Set 15 | puerto colombia
# Processing Record 16 of Set 15 | batsfjord
# Processing Record 17 of Set 15 | la macarena
# Processing Record 18 of Set 15 | takoradi
# Processing Record 19 of Set 15 | meulaboh
# Processing Record 20 of Set 15 | anchorage
# Processing Record 21 of Set 15 | klaksvik
# Processing Record 22 of Set 15 | asfi
# Processing Record 23 of Set 15 | terlizzi
# Processing Record 24 of Set 15 | sinnamary
# Processing Record 25 of Set 15 | zhangye
# Processing Record 26 of Set 15 | alindao
# Processing Record 27 of Set 15 | malaia
# Processing Record 28 of Set 15 | vaitape
# Processing Record 29 of Set 15 | wuwei
# Processing Record 30 of Set 15 | salalah
# Processing Record 31 of Set 15 | aleksandrov gay
# Processing Record 32 of Set 15 | howard springs
# Processing Record 33 of Set 15 | castrillon
# Processing Record 34 of Set 15 | chernyshevskiy
# Processing Record 35 of Set 15 | hailar
# Processing Record 36 of Set 15 | lorca
# Processing Record 37 of Set 15 | kikwit
# Processing Record 38 of Set 15 | cabanas
# Processing Record 39 of Set 15 | padang
# Processing Record 40 of Set 15 | finnsnes
# Processing Record 41 of Set 15 | trincomalee
# Processing Record 42 of Set 15 | chulman
# Processing Record 43 of Set 15 | west wendover
# Processing Record 44 of Set 15 | north bend
# Processing Record 45 of Set 15 | soubre
# Processing Record 46 of Set 15 | jardim
# Processing Record 47 of Set 15 | minas
# Processing Record 48 of Set 15 | labuhan
# Processing Record 49 of Set 15 | bairiki
# Processing Record 50 of Set 15 | taoudenni
# Processing Record 1 of Set 16 | batagay
# Processing Record 2 of Set 16 | mangalia
# Processing Record 3 of Set 16 | dibaya
# City not found. Skipping...
# Processing Record 4 of Set 16 | porto novo
# Processing Record 5 of Set 16 | xinzhi
# Processing Record 6 of Set 16 | torres
# Processing Record 7 of Set 16 | payo
# Processing Record 8 of Set 16 | kraksaan
# Processing Record 9 of Set 16 | khorramshahr
# Processing Record 10 of Set 16 | simao
# Processing Record 11 of Set 16 | opuwo
# Processing Record 12 of Set 16 | channel-port aux basques
# Processing Record 13 of Set 16 | lira
# Processing Record 14 of Set 16 | leshukonskoye
# Processing Record 15 of Set 16 | beruni
# City not found. Skipping...
# Processing Record 16 of Set 16 | santa isabel do rio negro
# Processing Record 17 of Set 16 | kalispell
# Processing Record 18 of Set 16 | udachnyy
# Processing Record 19 of Set 16 | spencer
# Processing Record 20 of Set 16 | katherine
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City Country                 Date      Lat       Lng  Max Temp  \
# 0      Albany      US  2021-09-18 22:45:36  42.6001  -73.9662     75.15
# 1      Evensk      RU  2021-09-18 22:46:03  61.9500  159.2333     46.62
# 2        Teya      RU  2021-09-18 22:46:03  60.3778   92.6267     44.67
# 3      Avarua      CK  2021-09-18 22:46:04 -21.2078 -159.7750     78.85
# 4       Kapaa      US  2021-09-18 22:46:04  22.0752 -159.3190     84.18
# 5  Nikolskoye      RU  2021-09-18 22:46:04  59.7035   30.7861     43.02
# 6      Contai      IN  2021-09-18 22:46:05  21.7786   87.7536     77.61
# 7    Thompson      CA  2021-09-18 22:46:06  55.7435  -97.8558     60.96
# 8   Busselton      AU  2021-09-18 22:46:06 -33.6500  115.3333     53.10
# 9        Lata      PT  2021-09-18 22:46:06  40.1629   -8.3327     62.82
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        75          60        7.63       broken clouds
# 1        99         100        7.96          light rain
# 2        95         100        2.91     overcast clouds
# 3        65          20       19.57          few clouds
# 4        69          20        7.00          few clouds
# 5        81         100        6.76     overcast clouds
# 6        92         100        2.93          light rain
# 7        51          90        3.44     overcast clouds
# 8        90          59        6.08       broken clouds
# 9        94           4        2.62           clear sky

# %%
# Create the output file (CSV).
output_data_file = "weather_database/weatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
